# %%
import tensorflow as tf

# %%
(train_x, train_y),(test_x, test_y) = tf.keras.datasets.mnist.load_data()
print(train_x.shape, train_y.shape)
print(test_x.shape, test_y.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
(cifar_train_x, cifar_train_y),(cifar_test_x, cifar_test_y) = tf.keras.datasets.cifar10.load_data()
print(cifar_train_x.shape, cifar_train_y.shape)
print(cifar_test_x.shape, cifar_test_y.shape)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 109s 1us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
# 화면출력

import matplotlib.pyplot as plt
print(train_y[0:10]) #0번째 숫자는 5
plt.imshow(train_x[0], cmap = 'gray')
plt.show()
print(cifar_train_y[0:10])  #1번쨰는 트럭
plt.imshow(cifar_train_x[1])
plt.show()
# Out:
# [5 0 4 1 9 2 1 3 1 4]
# [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]

# %%
# 차원확인

import numpy as np

d1 = np.array([1,2,3,4,5])
print(d1.ndim,d1.shape)

d2 = np.array([d1,d1,d1,d1])
print(d2.ndim, d2.shape)

d3 = np.array([d2,d2,d2])
print(d3.ndim, d3.shape)

d4 = np.array([d3,d3])
print(d4.ndim, d4.shape)
# Out:
# 1 (5,)
# 2 (4, 5)
# 3 (3, 4, 5)
# 4 (2, 3, 4, 5)
